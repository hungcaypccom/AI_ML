# %% [markdown]
# <a href="https://colab.research.google.com/github/hungcaypccom/AI_ML/blob/main/models/U2_Net_Untrained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Add

# %% [markdown]
# #initaial Wandb

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.0 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.38-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 22.0 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 23.7 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=de584673de355434bbaa12b7b456ff0c96da3b3af9e3f82ab740d4093861afed
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.38 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.32.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.15.12

# %%
import wandb
from wandb.keras import WandbCallback

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# #Model

# %% [markdown]
# ##Untrained Model

# %%
def conv_block(inputs, out_ch, rate=1):
    x = Conv2D(out_ch, 3, padding="same", dilation_rate=1)(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def RSU_L(inputs, out_ch, int_ch, num_layers, rate=2):
    """ Initial Conv """
    x = conv_block(inputs, out_ch)
    init_feats = x

    """ Encoder """
    skip = []
    x = conv_block(x, int_ch)
    skip.append(x)

    for i in range(num_layers-2):
        x = MaxPool2D((2, 2))(x)
        x = conv_block(x, int_ch)
        skip.append(x)

    """ Bridge """
    x = conv_block(x, int_ch, rate=rate)

    """ Decoder """
    skip.reverse()

    x = Concatenate()([x, skip[0]])
    x = conv_block(x, int_ch)

    for i in range(num_layers-3):
        x = UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
        x = Concatenate()([x, skip[i+1]])
        x = conv_block(x, int_ch)

    x = UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
    x = Concatenate()([x, skip[-1]])
    x = conv_block(x, out_ch)

    """ Add """
    x = Add()([x, init_feats])
    return x

# %%
def RSU_4F(inputs, out_ch, int_ch):
    """ Initial Conv """
    x0 = conv_block(inputs, out_ch, rate=1)

    """ Encoder """
    x1 = conv_block(x0, int_ch, rate=1)
    x2 = conv_block(x1, int_ch, rate=2)
    x3 = conv_block(x2, int_ch, rate=4)

    """ Bridge """
    x4 = conv_block(x3, int_ch, rate=8)

    """ Decoder """
    x = Concatenate()([x4, x3])
    x = conv_block(x, int_ch, rate=4)

    x = Concatenate()([x, x2])
    x = conv_block(x, int_ch, rate=2)

    x = Concatenate()([x, x1])
    x = conv_block(x, out_ch, rate=1)

    """ Addition """
    x = Add()([x, x0])
    return x

# %%
def u2net(input_shape, out_ch, int_ch, num_classes=1):
    """ Input Layer """
    inputs = Input(input_shape)
    s0 = inputs

    """ Encoder """
    s1 = RSU_L(s0, out_ch[0], int_ch[0], 7)
    p1 = MaxPool2D((2, 2))(s1)

    s2 = RSU_L(p1, out_ch[1], int_ch[1], 6)
    p2 = MaxPool2D((2, 2))(s2)

    s3 = RSU_L(p2, out_ch[2], int_ch[2], 5)
    p3 = MaxPool2D((2, 2))(s3)

    s4 = RSU_L(p3, out_ch[3], int_ch[3], 4)
    p4 = MaxPool2D((2, 2))(s4)

    s5 = RSU_4F(p4, out_ch[4], int_ch[4])
    p5 = MaxPool2D((2, 2))(s5)

    """ Bridge """
    b1 = RSU_4F(p5, out_ch[5], int_ch[5])
    b2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(b1)

    """ Decoder """
    d1 = Concatenate()([b2, s5])
    d1 = RSU_4F(d1, out_ch[6], int_ch[6])
    u1 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d1)

    d2 = Concatenate()([u1, s4])
    d2 = RSU_L(d2, out_ch[7], int_ch[7], 4)
    u2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d2)

    d3 = Concatenate()([u2, s3])
    d3 = RSU_L(d3, out_ch[8], int_ch[8], 5)
    u3 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d3)

    d4 = Concatenate()([u3, s2])
    d4 = RSU_L(d4, out_ch[9], int_ch[9], 6)
    u4 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d4)

    d5 = Concatenate()([u4, s1])
    d5 = RSU_L(d5, out_ch[10], int_ch[10], 7)

    """ Side Outputs """
    y1 = Conv2D(num_classes, 3, padding="same")(d5)

    y2 = Conv2D(num_classes, 3, padding="same")(d4)
    y2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(y2)

    y3 = Conv2D(num_classes, 3, padding="same")(d3)
    y3 = UpSampling2D(size=(4, 4), interpolation="bilinear")(y3)

    y4 = Conv2D(num_classes, 3, padding="same")(d2)
    y4 = UpSampling2D(size=(8, 8), interpolation="bilinear")(y4)

    y5 = Conv2D(num_classes, 3, padding="same")(d1)
    y5 = UpSampling2D(size=(16, 16), interpolation="bilinear")(y5)

    y6 = Conv2D(num_classes, 3, padding="same")(b1)
    y6 = UpSampling2D(size=(32, 32), interpolation="bilinear")(y6)

    y0 = Concatenate()([y1, y2, y3, y4, y5, y6])
    y0 = Conv2D(num_classes, 3, padding="same")(y0)

    y0 = Activation("sigmoid")(y0)
    y1 = Activation("sigmoid")(y1)
    y2 = Activation("sigmoid")(y2)
    y3 = Activation("sigmoid")(y3)
    y4 = Activation("sigmoid")(y4)
    y5 = Activation("sigmoid")(y5)
    y6 = Activation("sigmoid")(y6)

    model = tf.keras.models.Model(inputs, outputs=[y0, y1, y2, y3, y4, y5, y6])
    return model

# %%
def build_u2net(input_shape, num_classes=1):
    out_ch = [64, 128, 256, 512, 512, 512, 512, 256, 128, 64, 64]
    int_ch = [32, 32, 64, 128, 256, 256, 256, 128, 64, 32, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

# %%
def build_u2net_lite(input_shape, num_classes=1):
    out_ch = [64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64]
    int_ch = [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

# %%
input = (None, None, 3)
u2net_model = build_u2net(input)

# %%
u2net_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, None, None, 3)]      0         []
#
#  conv2d (Conv2D)             (None, None, None, 64)       1792      ['input_11[0][0]']
#
#  batch_normalization (Batch  (None, None, None, 64)       256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, None, None, 64)       0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)       18464     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, None, None, 32)       128       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, None, None, 32)       0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)       0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, None, None, 32)       9248      ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, None, None, 32)       128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, None, None, 32)       0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 32)       0         ['activation_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, None, None, 32)       9248      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, None, None, 32)       128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, None, None, 32)       0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, None, None, 32)       0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, None, None, 32)       9248      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, None, None, 32)       128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, None, None, 32)       0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, None, None, 32)       0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, None, None, 32)       9248      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, None, None, 32)       128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, None, None, 32)       0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_4 (MaxPoolin  (None, None, None, 32)       0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, None, None, 32)       9248      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, None, None, 32)       128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, None, None, 32)       0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, None, None, 32)       9248      ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, None, None, 32)       128       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, None, None, 32)       0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, None, None, 64)       0         ['activation_7[0][0]',
#                                                                      'activation_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, None, None, 32)       18464     ['concatenate[0][0]']
#
#  batch_normalization_8 (Bat  (None, None, None, 32)       128       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, None, None, 32)       0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  up_sampling2d (UpSampling2  (None, None, None, 32)       0         ['activation_8[0][0]']
#  D)
#
#  concatenate_1 (Concatenate  (None, None, None, 64)       0         ['up_sampling2d[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  conv2d_9 (Conv2D)           (None, None, None, 32)       18464     ['concatenate_1[0][0]']
#
#  batch_normalization_9 (Bat  (None, None, None, 32)       128       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, None, None, 32)       0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  up_sampling2d_1 (UpSamplin  (None, None, None, 32)       0         ['activation_9[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, None, None, 64)       0         ['up_sampling2d_1[0][0]',
#  )                                                                   'activation_4[0][0]']
#
#  conv2d_10 (Conv2D)          (None, None, None, 32)       18464     ['concatenate_2[0][0]']
#
#  batch_normalization_10 (Ba  (None, None, None, 32)       128       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, None, None, 32)       0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  up_sampling2d_2 (UpSamplin  (None, None, None, 32)       0         ['activation_10[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, None, None, 64)       0         ['up_sampling2d_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv2d_11 (Conv2D)          (None, None, None, 32)       18464     ['concatenate_3[0][0]']
#
#  batch_normalization_11 (Ba  (None, None, None, 32)       128       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, None, None, 32)       0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  up_sampling2d_3 (UpSamplin  (None, None, None, 32)       0         ['activation_11[0][0]']
#  g2D)
#
#  concatenate_4 (Concatenate  (None, None, None, 64)       0         ['up_sampling2d_3[0][0]',
#  )                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)          (None, None, None, 32)       18464     ['concatenate_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, None, None, 32)       128       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, None, None, 32)       0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  up_sampling2d_4 (UpSamplin  (None, None, None, 32)       0         ['activation_12[0][0]']
#  g2D)
#
#  concatenate_5 (Concatenate  (None, None, None, 64)       0         ['up_sampling2d_4[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, None, None, 64)       36928     ['concatenate_5[0][0]']
#
#  batch_normalization_13 (Ba  (None, None, None, 64)       256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, None, None, 64)       0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  add (Add)                   (None, None, None, 64)       0         ['activation_13[0][0]',
#                                                                      'activation[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, None, None, 64)       0         ['add[0][0]']
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, None, None, 128)      73856     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_14 (Ba  (None, None, None, 128)      512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, None, None, 128)      0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, None, None, 32)       36896     ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, None, None, 32)       128       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, None, None, 32)       0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, None, None, 32)       0         ['activation_15[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, None, None, 32)       9248      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_16 (Ba  (None, None, None, 32)       128       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, None, None, 32)       0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, None, None, 32)       0         ['activation_16[0][0]']
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, None, None, 32)       9248      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_17 (Ba  (None, None, None, 32)       128       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, None, None, 32)       0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, None, None, 32)       0         ['activation_17[0][0]']
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, None, None, 32)       9248      ['max_pooling2d_8[0][0]']
#
#  batch_normalization_18 (Ba  (None, None, None, 32)       128       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, None, None, 32)       0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  max_pooling2d_9 (MaxPoolin  (None, None, None, 32)       0         ['activation_18[0][0]']
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, None, None, 32)       9248      ['max_pooling2d_9[0][0]']
#
#  batch_normalization_19 (Ba  (None, None, None, 32)       128       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, None, None, 32)       0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, None, None, 32)       9248      ['activation_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, None, None, 32)       128       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, None, None, 32)       0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  concatenate_6 (Concatenate  (None, None, None, 64)       0         ['activation_20[0][0]',
#  )                                                                   'activation_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, None, None, 32)       18464     ['concatenate_6[0][0]']
#
#  batch_normalization_21 (Ba  (None, None, None, 32)       128       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, None, None, 32)       0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  up_sampling2d_5 (UpSamplin  (None, None, None, 32)       0         ['activation_21[0][0]']
#  g2D)
#
#  concatenate_7 (Concatenate  (None, None, None, 64)       0         ['up_sampling2d_5[0][0]',
#  )                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, None, None, 32)       18464     ['concatenate_7[0][0]']
#
#  batch_normalization_22 (Ba  (None, None, None, 32)       128       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, None, None, 32)       0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  up_sampling2d_6 (UpSamplin  (None, None, None, 32)       0         ['activation_22[0][0]']
#  g2D)
#
#  concatenate_8 (Concatenate  (None, None, None, 64)       0         ['up_sampling2d_6[0][0]',
#  )                                                                   'activation_17[0][0]']
#
#  conv2d_23 (Conv2D)          (None, None, None, 32)       18464     ['concatenate_8[0][0]']
#
#  batch_normalization_23 (Ba  (None, None, None, 32)       128       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, None, None, 32)       0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  up_sampling2d_7 (UpSamplin  (None, None, None, 32)       0         ['activation_23[0][0]']
#  g2D)
#
#  concatenate_9 (Concatenate  (None, None, None, 64)       0         ['up_sampling2d_7[0][0]',
#  )                                                                   'activation_16[0][0]']
#
#  conv2d_24 (Conv2D)          (None, None, None, 32)       18464     ['concatenate_9[0][0]']
#
#  batch_normalization_24 (Ba  (None, None, None, 32)       128       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, None, None, 32)       0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  up_sampling2d_8 (UpSamplin  (None, None, None, 32)       0         ['activation_24[0][0]']
#  g2D)
#
#  concatenate_10 (Concatenat  (None, None, None, 64)       0         ['up_sampling2d_8[0][0]',
#  e)                                                                  'activation_15[0][0]']
#
#  conv2d_25 (Conv2D)          (None, None, None, 128)      73856     ['concatenate_10[0][0]']
#
#  batch_normalization_25 (Ba  (None, None, None, 128)      512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, None, None, 128)      0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  add_1 (Add)                 (None, None, None, 128)      0         ['activation_25[0][0]',
#                                                                      'activation_14[0][0]']
#
#  max_pooling2d_10 (MaxPooli  (None, None, None, 128)      0         ['add_1[0][0]']
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, None, None, 256)      295168    ['max_pooling2d_10[0][0]']
#
#  batch_normalization_26 (Ba  (None, None, None, 256)      1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, None, None, 256)      0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, None, None, 64)       147520    ['activation_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, None, None, 64)       256       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, None, None, 64)       0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  max_pooling2d_11 (MaxPooli  (None, None, None, 64)       0         ['activation_27[0][0]']
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, None, None, 64)       36928     ['max_pooling2d_11[0][0]']
#
#  batch_normalization_28 (Ba  (None, None, None, 64)       256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, None, None, 64)       0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  max_pooling2d_12 (MaxPooli  (None, None, None, 64)       0         ['activation_28[0][0]']
#  ng2D)
#
#  conv2d_29 (Conv2D)          (None, None, None, 64)       36928     ['max_pooling2d_12[0][0]']
#
#  batch_normalization_29 (Ba  (None, None, None, 64)       256       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, None, None, 64)       0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_13 (MaxPooli  (None, None, None, 64)       0         ['activation_29[0][0]']
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, None, None, 64)       36928     ['max_pooling2d_13[0][0]']
#
#  batch_normalization_30 (Ba  (None, None, None, 64)       256       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, None, None, 64)       0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, None, None, 64)       36928     ['activation_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, None, None, 64)       256       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, None, None, 64)       0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  concatenate_11 (Concatenat  (None, None, None, 128)      0         ['activation_31[0][0]',
#  e)                                                                  'activation_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, None, None, 64)       73792     ['concatenate_11[0][0]']
#
#  batch_normalization_32 (Ba  (None, None, None, 64)       256       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, None, None, 64)       0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  up_sampling2d_9 (UpSamplin  (None, None, None, 64)       0         ['activation_32[0][0]']
#  g2D)
#
#  concatenate_12 (Concatenat  (None, None, None, 128)      0         ['up_sampling2d_9[0][0]',
#  e)                                                                  'activation_29[0][0]']
#
#  conv2d_33 (Conv2D)          (None, None, None, 64)       73792     ['concatenate_12[0][0]']
#
#  batch_normalization_33 (Ba  (None, None, None, 64)       256       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, None, None, 64)       0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  up_sampling2d_10 (UpSampli  (None, None, None, 64)       0         ['activation_33[0][0]']
#  ng2D)
#
#  concatenate_13 (Concatenat  (None, None, None, 128)      0         ['up_sampling2d_10[0][0]',
#  e)                                                                  'activation_28[0][0]']
#
#  conv2d_34 (Conv2D)          (None, None, None, 64)       73792     ['concatenate_13[0][0]']
#
#  batch_normalization_34 (Ba  (None, None, None, 64)       256       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, None, None, 64)       0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  up_sampling2d_11 (UpSampli  (None, None, None, 64)       0         ['activation_34[0][0]']
#  ng2D)
#
#  concatenate_14 (Concatenat  (None, None, None, 128)      0         ['up_sampling2d_11[0][0]',
#  e)                                                                  'activation_27[0][0]']
#
#  conv2d_35 (Conv2D)          (None, None, None, 256)      295168    ['concatenate_14[0][0]']
#
#  batch_normalization_35 (Ba  (None, None, None, 256)      1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, None, None, 256)      0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, None, None, 256)      0         ['activation_35[0][0]',
#                                                                      'activation_26[0][0]']
#
#  max_pooling2d_14 (MaxPooli  (None, None, None, 256)      0         ['add_2[0][0]']
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, None, None, 512)      1180160   ['max_pooling2d_14[0][0]']
#
#  batch_normalization_36 (Ba  (None, None, None, 512)      2048      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, None, None, 512)      0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, None, None, 128)      589952    ['activation_36[0][0]']
#
#  batch_normalization_37 (Ba  (None, None, None, 128)      512       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, None, None, 128)      0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  max_pooling2d_15 (MaxPooli  (None, None, None, 128)      0         ['activation_37[0][0]']
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, None, None, 128)      147584    ['max_pooling2d_15[0][0]']
#
#  batch_normalization_38 (Ba  (None, None, None, 128)      512       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, None, None, 128)      0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  max_pooling2d_16 (MaxPooli  (None, None, None, 128)      0         ['activation_38[0][0]']
#  ng2D)
#
#  conv2d_39 (Conv2D)          (None, None, None, 128)      147584    ['max_pooling2d_16[0][0]']
#
#  batch_normalization_39 (Ba  (None, None, None, 128)      512       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, None, None, 128)      0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, None, None, 128)      147584    ['activation_39[0][0]']
#
#  batch_normalization_40 (Ba  (None, None, None, 128)      512       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, None, None, 128)      0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  concatenate_15 (Concatenat  (None, None, None, 256)      0         ['activation_40[0][0]',
#  e)                                                                  'activation_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, None, None, 128)      295040    ['concatenate_15[0][0]']
#
#  batch_normalization_41 (Ba  (None, None, None, 128)      512       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, None, None, 128)      0         ['batch_normalization_41[0][0]
#                                                                     ']
#
# ...
#
#  conv2d_104 (Conv2D)         (None, None, None, 16)       2320      ['max_pooling2d_32[0][0]']
#
#  batch_normalization_104 (B  (None, None, None, 16)       64        ['conv2d_104[0][0]']
#  atchNormalization)
#
#  activation_104 (Activation  (None, None, None, 16)       0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  conv2d_105 (Conv2D)         (None, None, None, 16)       2320      ['activation_104[0][0]']
#
#  batch_normalization_105 (B  (None, None, None, 16)       64        ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_105 (Activation  (None, None, None, 16)       0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  concatenate_44 (Concatenat  (None, None, None, 32)       0         ['activation_105[0][0]',
#  e)                                                                  'activation_104[0][0]']
#
#  conv2d_106 (Conv2D)         (None, None, None, 16)       4624      ['concatenate_44[0][0]']
#
#  batch_normalization_106 (B  (None, None, None, 16)       64        ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, None, None, 16)       0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  up_sampling2d_28 (UpSampli  (None, None, None, 16)       0         ['activation_106[0][0]']
#  ng2D)
#
#  concatenate_45 (Concatenat  (None, None, None, 32)       0         ['up_sampling2d_28[0][0]',
#  e)                                                                  'activation_103[0][0]']
#
#  conv2d_107 (Conv2D)         (None, None, None, 16)       4624      ['concatenate_45[0][0]']
#
#  batch_normalization_107 (B  (None, None, None, 16)       64        ['conv2d_107[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, None, None, 16)       0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  up_sampling2d_29 (UpSampli  (None, None, None, 16)       0         ['activation_107[0][0]']
#  ng2D)
#
#  concatenate_46 (Concatenat  (None, None, None, 32)       0         ['up_sampling2d_29[0][0]',
#  e)                                                                  'activation_102[0][0]']
#
#  conv2d_108 (Conv2D)         (None, None, None, 16)       4624      ['concatenate_46[0][0]']
#
#  batch_normalization_108 (B  (None, None, None, 16)       64        ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, None, None, 16)       0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  up_sampling2d_30 (UpSampli  (None, None, None, 16)       0         ['activation_108[0][0]']
#  ng2D)
#
#  concatenate_47 (Concatenat  (None, None, None, 32)       0         ['up_sampling2d_30[0][0]',
#  e)                                                                  'activation_101[0][0]']
#
#  conv2d_109 (Conv2D)         (None, None, None, 16)       4624      ['concatenate_47[0][0]']
#
#  batch_normalization_109 (B  (None, None, None, 16)       64        ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, None, None, 16)       0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  up_sampling2d_31 (UpSampli  (None, None, None, 16)       0         ['activation_109[0][0]']
#  ng2D)
#
#  concatenate_48 (Concatenat  (None, None, None, 32)       0         ['up_sampling2d_31[0][0]',
#  e)                                                                  'activation_100[0][0]']
#
#  conv2d_110 (Conv2D)         (None, None, None, 16)       4624      ['concatenate_48[0][0]']
#
#  batch_normalization_110 (B  (None, None, None, 16)       64        ['conv2d_110[0][0]']
#  atchNormalization)
#
#  activation_110 (Activation  (None, None, None, 16)       0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  up_sampling2d_32 (UpSampli  (None, None, None, 16)       0         ['activation_110[0][0]']
#  ng2D)
#
#  concatenate_49 (Concatenat  (None, None, None, 32)       0         ['up_sampling2d_32[0][0]',
#  e)                                                                  'activation_99[0][0]']
#
#  conv2d_111 (Conv2D)         (None, None, None, 64)       18496     ['concatenate_49[0][0]']
#
#  batch_normalization_111 (B  (None, None, None, 64)       256       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  activation_111 (Activation  (None, None, None, 64)       0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  add_10 (Add)                (None, None, None, 64)       0         ['activation_111[0][0]',
#                                                                      'activation_98[0][0]']
#
#  conv2d_113 (Conv2D)         (None, None, None, 1)        577       ['add_9[0][0]']
#
#  conv2d_114 (Conv2D)         (None, None, None, 1)        1153      ['add_8[0][0]']
#
#  conv2d_115 (Conv2D)         (None, None, None, 1)        2305      ['add_7[0][0]']
#
#  conv2d_116 (Conv2D)         (None, None, None, 1)        4609      ['add_6[0][0]']
#
#  conv2d_117 (Conv2D)         (None, None, None, 1)        4609      ['add_5[0][0]']
#
#  conv2d_112 (Conv2D)         (None, None, None, 1)        577       ['add_10[0][0]']
#
#  up_sampling2d_33 (UpSampli  (None, None, None, 1)        0         ['conv2d_113[0][0]']
#  ng2D)
#
#  up_sampling2d_34 (UpSampli  (None, None, None, 1)        0         ['conv2d_114[0][0]']
#  ng2D)
#
#  up_sampling2d_35 (UpSampli  (None, None, None, 1)        0         ['conv2d_115[0][0]']
#  ng2D)
#
#  up_sampling2d_36 (UpSampli  (None, None, None, 1)        0         ['conv2d_116[0][0]']
#  ng2D)
#
#  up_sampling2d_37 (UpSampli  (None, None, None, 1)        0         ['conv2d_117[0][0]']
#  ng2D)
#
#  concatenate_50 (Concatenat  (None, None, None, 6)        0         ['conv2d_112[0][0]',
#  e)                                                                  'up_sampling2d_33[0][0]',
#                                                                      'up_sampling2d_34[0][0]',
#                                                                      'up_sampling2d_35[0][0]',
#                                                                      'up_sampling2d_36[0][0]',
#                                                                      'up_sampling2d_37[0][0]']
#
#  conv2d_118 (Conv2D)         (None, None, None, 1)        55        ['concatenate_50[0][0]']
#
#  activation_112 (Activation  (None, None, None, 1)        0         ['conv2d_118[0][0]']
#  )
#
#  activation_113 (Activation  (None, None, None, 1)        0         ['conv2d_112[0][0]']
#  )
#
#  activation_114 (Activation  (None, None, None, 1)        0         ['up_sampling2d_33[0][0]']
#  )
#
#  activation_115 (Activation  (None, None, None, 1)        0         ['up_sampling2d_34[0][0]']
#  )
#
#  activation_116 (Activation  (None, None, None, 1)        0         ['up_sampling2d_35[0][0]']
#  )
#
#  activation_117 (Activation  (None, None, None, 1)        0         ['up_sampling2d_36[0][0]']
#  )
#
#  activation_118 (Activation  (None, None, None, 1)        0         ['up_sampling2d_37[0][0]']
#  )
#
# ==================================================================================================
# Total params: 44038717 (167.99 MB)
# Trainable params: 44009917 (167.88 MB)
# Non-trainable params: 28800 (112.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ###Log Model to Wandb

# %%
def log_model():
  with wandb.init(project="U2-net", entity="hungcaypccom") as run:

    untrained_model = wandb.Artifact(
        name = "U2net_Untrained_model",
        type="model",
        description = "The initial version of our U2net model",

    )
    filename = 'Untrained_U2net.h5'
    u2net_model.save(filename)

    untrained_model.add_file(filename)
    wandb.save(filename)
    run.log_artifact(untrained_model)

# %%
log_model()
# Out:
# wandb: Currently logged in as: hungcaypccom. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231017_084736-fp22g3al</code>
# Syncing run <strong><a href='https://wandb.ai/hungcaypccom/U2-net/runs/fp22g3al' target="_blank">young-rain-1</a></strong> to <a href='https://wandb.ai/hungcaypccom/U2-net' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hungcaypccom/U2-net' target="_blank">https://wandb.ai/hungcaypccom/U2-net</a>
#  View run at <a href='https://wandb.ai/hungcaypccom/U2-net/runs/fp22g3al' target="_blank">https://wandb.ai/hungcaypccom/U2-net/runs/fp22g3al</a>
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">young-rain-1</strong> at: <a href='https://wandb.ai/hungcaypccom/U2-net/runs/fp22g3al' target="_blank">https://wandb.ai/hungcaypccom/U2-net/runs/fp22g3al</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231017_084736-fp22g3al/logs</code>
